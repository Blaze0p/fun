# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/placement.csv')
# Out:
# Drive already mounted at /content/placement.csv; to attempt to forcibly remount, call drive.mount("/content/placement.csv", force_remount=True).

# %% [markdown]
# so this is a placement ml model
#
# libraries used pandas, numpy, scikit learn (sklearn.linear_model) , matplotlib (import matplotlib.pyplot as plt)
# scikit lear(sklearn.prepocessing import standardscaler)

# %%
df = pd.read_csv('/content/placement.csv/MyDrive/placement.csv')
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
# Instead of assigning the result of df.info() to df,
# simply call it to print the information.
df.info()

# Now you can access df.shape since df still refers to the DataFrame.
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB
# (100, 4)

# %% [markdown]
# using required columns
# we have to remove username

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
'''plt.scatter(x["CGPA"], x["IQ"])
plt.show() '''

plt.scatter(df['cgpa'],df['iq'], c=df['placement'])
plt.show()

# %%
a = df.iloc[:,1:3]
b = df.iloc[:,-1]

# %%
a
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
b
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# we are using logical regression
#
# --- its a supervised data
# --- use classification (cgpa)
# ---------------------- (iq)
# -----------------------(placement)

# %%
a_train,a_test,b_train,b_test = train_test_split(a,b,test_size=0.1)

# %% [markdown]
# x = df.iloc[:,1:3]
# y = df.iloc[:,-1]
# spliting into training sets and test sets

# %%
a_train
# Out:
#     cgpa     iq
# 8    6.1  156.0
# 76   4.9  155.0
# 83   7.5  130.0
# 28   5.2   90.0
# 91   7.5  158.0
# ..   ...    ...
# 47   5.2  161.0
# 52   7.0  175.0
# 74   6.7  154.0
# 82   6.5   37.0
# 42   7.6   89.0
#
# [90 rows x 2 columns]

# %%
b_train
# Out:
# 8     0
# 76    0
# 83    1
# 28    0
# 91    1
#      ..
# 47    0
# 52    1
# 74    1
# 82    1
# 42    1
# Name: placement, Length: 90, dtype: int64

# %%
a_test
# Out:
#     cgpa     iq
# 62   6.0  102.0
# 1    5.9  106.0
# 25   5.0   91.0
# 87   5.7  132.0
# 55   7.8  114.0
# 41   5.4  114.0
# 88   4.4  149.0
# 66   6.9   96.0
# 6    5.7  143.0
# 9    5.1   66.0

# %% [markdown]
# its only picking up  ten at random randint range b/w (0 ,100 )  and same goes with other tester
#
# testers = x_test, y_test

# %%
from sklearn.preprocessing import StandardScaler
scaler_ = StandardScaler()

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# as_ = StandardScaler()
#
#
# to scale

# %%
a_train = scaler_ .fit_transform(a_train)
a_test = scaler_ .transform(a_test)

# %%
a_train
# Out:
# array([[ 0.07489841,  0.75918397],
#        [-0.96215654,  0.73473798],
#        [ 1.28479586,  0.12358809],
#        [-0.7028928 , -0.85425173],
#        [ 1.28479586,  0.80807596],
#        [-1.13499903, -1.78319956],
#        [-1.73994775, -0.60979178],
#        [ 0.07489841, -1.46540162],
#        [-0.18436532,  1.00364393],
#        [ 0.85268963,  0.34360205],
#        [ 0.67984713, -0.85425173],
#        [ 1.11195336, -1.83209155],
#        [-0.87573529, -0.16976386],
#        [-0.53005031, -0.43866981],
#        [ 0.59342589,  1.39477985],
#        [ 1.19837461,  0.17248008],
#        [-1.04857778,  0.39249404],
#        [-0.53005031,  0.34360205],
#        [ 0.07489841, -1.07426569],
#        [-0.7028928 ,  2.42151167],
#        [ 0.50700464,  0.31915605],
#        [ 0.85268963, -1.48984761],
#        [-1.48068401,  1.83480777],
#        [ 0.67984713, -0.31643983],
#        [ 1.97616582,  1.05253592],
#        [ 1.80332333,  1.00364393],
#        [-0.61647155, -0.09642587],
# ...

# %%
a_test
# Out:
# array([[-0.01152283, -0.56089979],
#        [-0.09794408, -0.4631158 ],
#        [-0.87573529, -0.82980574],
#        [-0.27078657,  0.17248008],
#        [ 1.54405959, -0.26754784],
#        [-0.53005031, -0.26754784],
#        [-1.39426277,  0.588062  ],
#        [ 0.76626838, -0.70757576],
#        [-0.27078657,  0.44138603],
#        [-0.78931405, -1.44095562]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(a_train,b_train)
# Out:
# LogisticRegression()

# %%
b_pred = clf.predict(a_test)

# %%
b_test
# Out:
# 62    0
# 1     0
# 25    0
# 87    1
# 55    1
# 41    0
# 88    0
# 66    1
# 6     0
# 9     0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(b_test,b_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(a_train, b_train.values, clf=clf, legend=2) # Now plot the decision regions
# Out:
# <Axes: >
